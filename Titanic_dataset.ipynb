# %% [markdown]
# <a href="https://colab.research.google.com/github/riyasen-cell/iris-dataset/blob/main/Titanic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TITANIC DATASET - Machine learning Assignment
#
# This notebool applies multiple machine learnig algorithms
# (Naive Bayes, MLP,Decision Tree, Random Forest, SVM , KNN)
# On the Titanic dataset using different train_test splits ( 80:20 , 70:30 , 50:50) .
# The performance is evaluated using accuracy score.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# Load dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Preprocessing
df = df[['Pclass', 'Sex', 'Age','SibSp', 'Parch', 'Fare', 'Survived']]
df.dropna(inplace=True)
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

X = df.drop('Survived', axis=1)
y = df['Survived']

models = {"Naive_Bayes": GaussianNB(),
          "MLP": MLPClassifier(max_iter=500),
          "DecisionTree": DecisionTreeClassifier(),
          "RandomForest": RandomForestClassifier(),
          "SVM": SVC(),
          "KNN": KNeighborsClassifier()
          }
splits = [0.2, 0.3, 0.5]

for split in splits:
    print(f"\nTrain_Test_Split: {int((1-split)*100)}:{int(split*100)}")
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split, random_state=42)

    for model_name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        print(f"{model_name} : {round(accuracy , 3)}")
# Out:
# Train_Test_Split: 80:20
# Naive_Bayes : 0.762
# MLP : 0.741
# DecisionTree : 0.713
# RandomForest : 0.776
# SVM : 0.622
# KNN : 0.65
#
# Train_Test_Split: 70:30
# Naive_Bayes : 0.777
# MLP : 0.772
# DecisionTree : 0.74
# RandomForest : 0.795
# SVM : 0.67
# KNN : 0.674
#
# Train_Test_Split: 50:50
# Naive_Bayes : 0.773
# MLP : 0.798
# DecisionTree : 0.765
# RandomForest : 0.804
# SVM : 0.655
# KNN : 0.714
